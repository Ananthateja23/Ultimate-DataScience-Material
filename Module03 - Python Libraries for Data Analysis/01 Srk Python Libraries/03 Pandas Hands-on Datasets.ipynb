# %%
import numpy as np
import pandas as pd

# %%
#df = pd.read_csv("D:\\DataScience\\ClassVideos\\02_PythonLibraries\\Track_01\\Tips.csv")
df = pd.read_csv("Tips.csv")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
pd.set_option("display.max_rows",None)

# %%
#df = pd.read_csv("D:\\DataScience\\ClassVideos\\02_PythonLibraries\\Track_01\\Tips.csv")
df = pd.read_csv("Tips.csv")
df
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 0         16.99   1.01  Female     No   Sun  Dinner     2
# 1         10.34   1.66    Male     No   Sun  Dinner     3
# 2         21.01   3.50    Male     No   Sun  Dinner     3
# 3         23.68   3.31    Male     No   Sun  Dinner     2
# 4         24.59   3.61  Female     No   Sun  Dinner     4
# 5         25.29   4.71    Male     No   Sun  Dinner     4
# 6          8.77   2.00    Male     No   Sun  Dinner     2
# 7         26.88   3.12    Male     No   Sun  Dinner     4
# 8         15.04   1.96    Male     No   Sun  Dinner     2
# 9         14.78   3.23    Male     No   Sun  Dinner     2
# 10        10.27   1.71    Male     No   Sun  Dinner     2
# 11        35.26   5.00  Female     No   Sun  Dinner     4
# 12        15.42   1.57    Male     No   Sun  Dinner     2
# 13        18.43   3.00    Male     No   Sun  Dinner     4
# 14        14.83   3.02  Female     No   Sun  Dinner     2
# ...

# %%
#df = pd.read_csv("D:\\DataScience\\ClassVideos\\02_PythonLibraries\\Track_01\\Tips.csv")
df = pd.read_csv("Tips.csv")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.tail(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.shape
# Out:
# (244, 7)

# %%
df.size
# Out:
# 1708

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df.keys()
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df.dtypes
# Out:
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size            int64
# dtype: object

# %%
df['total_bill'].unique()
# Out:
# array([16.99, 10.34, 21.01, 23.68, 24.59, 25.29,  8.77, 26.88, 15.04,
#        14.78, 10.27, 35.26, 15.42, 18.43, 14.83, 21.58, 10.33, 16.29,
#        16.97, 20.65, 17.92, 20.29, 15.77, 39.42, 19.82, 17.81, 13.37,
#        12.69, 21.7 , 19.65,  9.55, 18.35, 15.06, 20.69, 17.78, 24.06,
#        16.31, 16.93, 18.69, 31.27, 16.04, 17.46, 13.94,  9.68, 30.4 ,
#        18.29, 22.23, 32.4 , 28.55, 18.04, 12.54, 10.29, 34.81,  9.94,
#        25.56, 19.49, 38.01, 26.41, 11.24, 48.27, 13.81, 11.02, 17.59,
#        20.08, 16.45,  3.07, 20.23, 15.01, 12.02, 17.07, 26.86, 25.28,
#        14.73, 10.51, 27.2 , 22.76, 17.29, 19.44, 16.66, 10.07, 32.68,
#        15.98, 34.83, 13.03, 18.28, 24.71, 21.16, 28.97, 22.49,  5.75,
#        16.32, 22.75, 40.17, 27.28, 12.03, 12.46, 11.35, 15.38, 44.3 ,
#        22.42, 20.92, 15.36, 20.49, 25.21, 18.24, 14.31, 14.  ,  7.25,
#        38.07, 23.95, 25.71, 17.31, 29.93, 10.65, 12.43, 24.08, 11.69,
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df = df.rename(columns = {'sex':'gender', 'size': 'no_of_members'})
df.head()
# Out:
#    total_bill   tip  gender smoker  day    time  no_of_members
# 0       16.99  1.01  Female     No  Sun  Dinner              2
# 1       10.34  1.66    Male     No  Sun  Dinner              3
# 2       21.01  3.50    Male     No  Sun  Dinner              3
# 3       23.68  3.31    Male     No  Sun  Dinner              2
# 4       24.59  3.61  Female     No  Sun  Dinner              4

# %%
df.iloc[0]
# Out:
# total_bill        16.99
# tip                1.01
# gender           Female
# smoker               No
# day                 Sun
# time             Dinner
# no_of_members         2
# Name: 0, dtype: object

# %%
df.iloc[[0,1]]
# Out:
#    total_bill   tip  gender smoker  day    time  no_of_members
# 0       16.99  1.01  Female     No  Sun  Dinner              2
# 1       10.34  1.66    Male     No  Sun  Dinner              3

# %%
df.iloc[0:3]
# Out:
#    total_bill   tip  gender smoker  day    time  no_of_members
# 0       16.99  1.01  Female     No  Sun  Dinner              2
# 1       10.34  1.66    Male     No  Sun  Dinner              3
# 2       21.01  3.50    Male     No  Sun  Dinner              3

# %%
df.iloc[0,0]
# Out:
# 16.99

# %%
df.iloc[[0,1],[0,1,2]]
# Out:
#    total_bill   tip  gender
# 0       16.99  1.01  Female
# 1       10.34  1.66    Male

# %%
df.iloc[0:3,0:7]
# Out:
#    total_bill   tip  gender smoker  day    time  no_of_members
# 0       16.99  1.01  Female     No  Sun  Dinner              2
# 1       10.34  1.66    Male     No  Sun  Dinner              3
# 2       21.01  3.50    Male     No  Sun  Dinner              3

# %%
df.loc[0]
# Out:
# total_bill        16.99
# tip                1.01
# gender           Female
# smoker               No
# day                 Sun
# time             Dinner
# no_of_members         2
# Name: 0, dtype: object

# %%
df.loc[[0,1]]
# Out:
#    total_bill   tip  gender smoker  day    time  no_of_members
# 0       16.99  1.01  Female     No  Sun  Dinner              2
# 1       10.34  1.66    Male     No  Sun  Dinner              3

# %%
df.loc[0:2]
# Out:
#    total_bill   tip  gender smoker  day    time  no_of_members
# 0       16.99  1.01  Female     No  Sun  Dinner              2
# 1       10.34  1.66    Male     No  Sun  Dinner              3
# 2       21.01  3.50    Male     No  Sun  Dinner              3

# %%
df.loc[0,'total_bill']
# Out:
# 16.99

# %%
df.loc[[0,1],['total_bill', 'tip', 'gender']]
# Out:
#    total_bill   tip  gender
# 0       16.99  1.01  Female
# 1       10.34  1.66    Male

# %%
df.loc[0:2,'total_bill']
# Out:
# 0    16.99
# 1    10.34
# 2    21.01
# Name: total_bill, dtype: float64

# %%
df.loc[0:2,['total_bill']]
# Out:
#    total_bill
# 0       16.99
# 1       10.34
# 2       21.01

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'gender', 'smoker', 'day', 'time',
#        'no_of_members'],
#       dtype='object')

# %%
df.loc[0:2,['total_bill', 'tip', 'gender', 'smoker', 'day', 'time', 'no_of_members']]
# Out:
#    total_bill   tip  gender smoker  day    time  no_of_members
# 0       16.99  1.01  Female     No  Sun  Dinner              2
# 1       10.34  1.66    Male     No  Sun  Dinner              3
# 2       21.01  3.50    Male     No  Sun  Dinner              3

# %% [markdown]
# # To select first column of all records of dataframe:

# %%
df.iloc[:, 0]
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
# 5      25.29
# 6       8.77
# 7      26.88
# 8      15.04
# 9      14.78
# 10     10.27
# 11     35.26
# 12     15.42
# 13     18.43
# 14     14.83
# 15     21.58
# 16     10.33
# 17     16.29
# 18     16.97
# 19     20.65
# 20     17.92
# 21     20.29
# 22     15.77
# 23     39.42
# 24     19.82
# 25     17.81
# 26     13.37
# 27     12.69
# 28     21.70
# 29     19.65
# 30      9.55
# 31     18.35
# 32     15.06
# 33     20.69
# 34     17.78
# 35     24.06
# 36     16.31
# 37     16.93
# 38     18.69
# 39     31.27
# 40     16.04
# 41     17.46
# 42     13.94
# 43      9.68
# 44     30.40
# 45     18.29
# 46     22.23
# 47     32.40
# 48     28.55
# 49     18.04
# 50     12.54
# 51     10.29
# 52     34.81
# 53      9.94
# 54     25.56
# 55     19.49
# 56     38.01
# 57     26.41
# 58     11.24
# 59     48.27
# 60     20.29
# 61     13.81
# 62     11.02
# 63     18.29
# 64     17.59
# 65     20.08
# ...

# %%
df.loc[:,'total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
# 5      25.29
# 6       8.77
# 7      26.88
# 8      15.04
# 9      14.78
# 10     10.27
# 11     35.26
# 12     15.42
# 13     18.43
# 14     14.83
# 15     21.58
# 16     10.33
# 17     16.29
# 18     16.97
# 19     20.65
# 20     17.92
# 21     20.29
# 22     15.77
# 23     39.42
# 24     19.82
# 25     17.81
# 26     13.37
# 27     12.69
# 28     21.70
# 29     19.65
# 30      9.55
# 31     18.35
# 32     15.06
# 33     20.69
# 34     17.78
# 35     24.06
# 36     16.31
# 37     16.93
# 38     18.69
# 39     31.27
# 40     16.04
# 41     17.46
# 42     13.94
# 43      9.68
# 44     30.40
# 45     18.29
# 46     22.23
# 47     32.40
# 48     28.55
# 49     18.04
# 50     12.54
# 51     10.29
# 52     34.81
# 53      9.94
# 54     25.56
# 55     19.49
# 56     38.01
# 57     26.41
# 58     11.24
# 59     48.27
# 60     20.29
# 61     13.81
# 62     11.02
# 63     18.29
# 64     17.59
# 65     20.08
# ...

# %%
df.total_bill
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
# 5      25.29
# 6       8.77
# 7      26.88
# 8      15.04
# 9      14.78
# 10     10.27
# 11     35.26
# 12     15.42
# 13     18.43
# 14     14.83
# 15     21.58
# 16     10.33
# 17     16.29
# 18     16.97
# 19     20.65
# 20     17.92
# 21     20.29
# 22     15.77
# 23     39.42
# 24     19.82
# 25     17.81
# 26     13.37
# 27     12.69
# 28     21.70
# 29     19.65
# 30      9.55
# 31     18.35
# 32     15.06
# 33     20.69
# 34     17.78
# 35     24.06
# 36     16.31
# 37     16.93
# 38     18.69
# 39     31.27
# 40     16.04
# 41     17.46
# 42     13.94
# 43      9.68
# 44     30.40
# 45     18.29
# 46     22.23
# 47     32.40
# 48     28.55
# 49     18.04
# 50     12.54
# 51     10.29
# 52     34.81
# 53      9.94
# 54     25.56
# 55     19.49
# 56     38.01
# 57     26.41
# 58     11.24
# 59     48.27
# 60     20.29
# 61     13.81
# 62     11.02
# 63     18.29
# 64     17.59
# 65     20.08
# ...

# %%
df['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
# 5      25.29
# 6       8.77
# 7      26.88
# 8      15.04
# 9      14.78
# 10     10.27
# 11     35.26
# 12     15.42
# 13     18.43
# 14     14.83
# 15     21.58
# 16     10.33
# 17     16.29
# 18     16.97
# 19     20.65
# 20     17.92
# 21     20.29
# 22     15.77
# 23     39.42
# 24     19.82
# 25     17.81
# 26     13.37
# 27     12.69
# 28     21.70
# 29     19.65
# 30      9.55
# 31     18.35
# 32     15.06
# 33     20.69
# 34     17.78
# 35     24.06
# 36     16.31
# 37     16.93
# 38     18.69
# 39     31.27
# 40     16.04
# 41     17.46
# 42     13.94
# 43      9.68
# 44     30.40
# 45     18.29
# 46     22.23
# 47     32.40
# 48     28.55
# 49     18.04
# 50     12.54
# 51     10.29
# 52     34.81
# 53      9.94
# 54     25.56
# 55     19.49
# 56     38.01
# 57     26.41
# 58     11.24
# 59     48.27
# 60     20.29
# 61     13.81
# 62     11.02
# 63     18.29
# 64     17.59
# 65     20.08
# ...

# %%
df[['total_bill']]
# Out:
#      total_bill
# 0         16.99
# 1         10.34
# 2         21.01
# 3         23.68
# 4         24.59
# 5         25.29
# 6          8.77
# 7         26.88
# 8         15.04
# 9         14.78
# 10        10.27
# 11        35.26
# 12        15.42
# 13        18.43
# 14        14.83
# 15        21.58
# 16        10.33
# 17        16.29
# 18        16.97
# 19        20.65
# 20        17.92
# 21        20.29
# 22        15.77
# 23        39.42
# 24        19.82
# 25        17.81
# 26        13.37
# 27        12.69
# 28        21.70
# 29        19.65
# 30         9.55
# 31        18.35
# 32        15.06
# 33        20.69
# 34        17.78
# 35        24.06
# 36        16.31
# 37        16.93
# 38        18.69
# 39        31.27
# 40        16.04
# 41        17.46
# 42        13.94
# 43         9.68
# 44        30.40
# 45        18.29
# 46        22.23
# 47        32.40
# 48        28.55
# 49        18.04
# 50        12.54
# 51        10.29
# 52        34.81
# 53         9.94
# ...

# %% [markdown]
# # To select the single column of all records
#     syntax: df[column]
# # To select the multiple columns of all records
#     syntax: df[list of column names]

# %%
df['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
# 5      25.29
# 6       8.77
# 7      26.88
# 8      15.04
# 9      14.78
# 10     10.27
# 11     35.26
# 12     15.42
# 13     18.43
# 14     14.83
# 15     21.58
# 16     10.33
# 17     16.29
# 18     16.97
# 19     20.65
# 20     17.92
# 21     20.29
# 22     15.77
# 23     39.42
# 24     19.82
# 25     17.81
# 26     13.37
# 27     12.69
# 28     21.70
# 29     19.65
# 30      9.55
# 31     18.35
# 32     15.06
# 33     20.69
# 34     17.78
# 35     24.06
# 36     16.31
# 37     16.93
# 38     18.69
# 39     31.27
# 40     16.04
# 41     17.46
# 42     13.94
# 43      9.68
# 44     30.40
# 45     18.29
# 46     22.23
# 47     32.40
# 48     28.55
# 49     18.04
# 50     12.54
# 51     10.29
# 52     34.81
# 53      9.94
# 54     25.56
# 55     19.49
# 56     38.01
# 57     26.41
# 58     11.24
# 59     48.27
# 60     20.29
# 61     13.81
# 62     11.02
# 63     18.29
# 64     17.59
# 65     20.08
# ...

# %%
df[['total_bill', 'tip', 'gender', 'smoker', 'day', 'time', 'no_of_members']]
# Out:
#      total_bill    tip  gender smoker   day    time  no_of_members
# 0         16.99   1.01  Female     No   Sun  Dinner              2
# 1         10.34   1.66    Male     No   Sun  Dinner              3
# 2         21.01   3.50    Male     No   Sun  Dinner              3
# 3         23.68   3.31    Male     No   Sun  Dinner              2
# 4         24.59   3.61  Female     No   Sun  Dinner              4
# 5         25.29   4.71    Male     No   Sun  Dinner              4
# 6          8.77   2.00    Male     No   Sun  Dinner              2
# 7         26.88   3.12    Male     No   Sun  Dinner              4
# 8         15.04   1.96    Male     No   Sun  Dinner              2
# 9         14.78   3.23    Male     No   Sun  Dinner              2
# 10        10.27   1.71    Male     No   Sun  Dinner              2
# 11        35.26   5.00  Female     No   Sun  Dinner              4
# 12        15.42   1.57    Male     No   Sun  Dinner              2
# ...

# %%
df['total_bill'].shape
# Out:
# (244,)

# %%
df[['total_bill', 'tip', 'gender', 'smoker', 'day', 'time', 'no_of_members']].shape
# Out:
# (244, 7)

# %%
df['total_bill'].values
# Out:
# array([16.99, 10.34, 21.01, 23.68, 24.59, 25.29,  8.77, 26.88, 15.04,
#        14.78, 10.27, 35.26, 15.42, 18.43, 14.83, 21.58, 10.33, 16.29,
#        16.97, 20.65, 17.92, 20.29, 15.77, 39.42, 19.82, 17.81, 13.37,
#        12.69, 21.7 , 19.65,  9.55, 18.35, 15.06, 20.69, 17.78, 24.06,
#        16.31, 16.93, 18.69, 31.27, 16.04, 17.46, 13.94,  9.68, 30.4 ,
#        18.29, 22.23, 32.4 , 28.55, 18.04, 12.54, 10.29, 34.81,  9.94,
#        25.56, 19.49, 38.01, 26.41, 11.24, 48.27, 20.29, 13.81, 11.02,
#        18.29, 17.59, 20.08, 16.45,  3.07, 20.23, 15.01, 12.02, 17.07,
#        26.86, 25.28, 14.73, 10.51, 17.92, 27.2 , 22.76, 17.29, 19.44,
#        16.66, 10.07, 32.68, 15.98, 34.83, 13.03, 18.28, 24.71, 21.16,
#        28.97, 22.49,  5.75, 16.32, 22.75, 40.17, 27.28, 12.03, 21.01,
#        12.46, 11.35, 15.38, 44.3 , 22.42, 20.92, 15.36, 20.49, 25.21,
#        18.24, 14.31, 14.  ,  7.25, 38.07, 23.95, 25.71, 17.31, 29.93,
# ...

# %%
df[['total_bill', 'tip', 'gender', 'smoker', 'day', 'time', 'no_of_members']].to_numpy()
# Out:
# array([[16.99, 1.01, 'Female', ..., 'Sun', 'Dinner', 2],
#        [10.34, 1.66, 'Male', ..., 'Sun', 'Dinner', 3],
#        [21.01, 3.5, 'Male', ..., 'Sun', 'Dinner', 3],
#        ...,
#        [22.67, 2.0, 'Male', ..., 'Sat', 'Dinner', 2],
#        [17.82, 1.75, 'Male', ..., 'Sat', 'Dinner', 2],
#        [18.78, 3.0, 'Female', ..., 'Thur', 'Dinner', 2]], dtype=object)

# %% [markdown]
# # filtering
#     (1) df[condition]
#     (2) df[condition1 or condition2]

# %%
df1 = pd.DataFrame({'X': [1,2,3,4,5], 'Y':[6,7,8,9,10]})
df1
df1[df1['X']>=4]
# Out:
#    X   Y
# 3  4   9
# 4  5  10

# %%
df1[df1['X']==4]['X']
# Out:
# 3    4
# Name: X, dtype: int64

# %%
df1[df1['X']==4]['X'].index
# Out:
# Index([3], dtype='int64')

# %%
df1[df1['X']==4]['X'].index[0]
# Out:
# 3

# %%
df[(df["tip"]>=7)]
# Out:
#      total_bill    tip gender smoker  day    time  no_of_members
# 23        39.42   7.58   Male     No  Sat  Dinner              4
# 170       50.81  10.00   Male    Yes  Sat  Dinner              3
# 212       48.33   9.00   Male     No  Sat  Dinner              4

# %%
df[(df["gender"]=='Male')]
# Out:
#      total_bill    tip gender smoker   day    time  no_of_members
# 1         10.34   1.66   Male     No   Sun  Dinner              3
# 2         21.01   3.50   Male     No   Sun  Dinner              3
# 3         23.68   3.31   Male     No   Sun  Dinner              2
# 5         25.29   4.71   Male     No   Sun  Dinner              4
# 6          8.77   2.00   Male     No   Sun  Dinner              2
# 7         26.88   3.12   Male     No   Sun  Dinner              4
# 8         15.04   1.96   Male     No   Sun  Dinner              2
# 9         14.78   3.23   Male     No   Sun  Dinner              2
# 10        10.27   1.71   Male     No   Sun  Dinner              2
# 12        15.42   1.57   Male     No   Sun  Dinner              2
# 13        18.43   3.00   Male     No   Sun  Dinner              4
# 15        21.58   3.92   Male     No   Sun  Dinner              2
# 17        16.29   3.71   Male     No   Sun  Dinner              3
# ...

# %%
df[(df['total_bill']>40) & (df['gender']=='Female')]
# Out:
#      total_bill  tip  gender smoker   day    time  no_of_members
# 102       44.30  2.5  Female    Yes   Sat  Dinner              3
# 197       43.11  5.0  Female    Yes  Thur   Lunch              4

# %%
df[(df['total_bill']>40) & (df['gender']=='Male')]
# Out:
#      total_bill    tip gender smoker   day    time  no_of_members
# 59        48.27   6.73   Male     No   Sat  Dinner              4
# 95        40.17   4.73   Male    Yes   Fri  Dinner              4
# 142       41.19   5.00   Male     No  Thur   Lunch              5
# 156       48.17   5.00   Male     No   Sun  Dinner              6
# 170       50.81  10.00   Male    Yes   Sat  Dinner              3
# 182       45.35   3.50   Male    Yes   Sun  Dinner              3
# 184       40.55   3.00   Male    Yes   Sun  Dinner              2
# 212       48.33   9.00   Male     No   Sat  Dinner              4

# %%
df[(df["tip"]>=7) | (df["no_of_members"]==6)]
# Out:
#      total_bill    tip  gender smoker   day    time  no_of_members
# 23        39.42   7.58    Male     No   Sat  Dinner              4
# 125       29.80   4.20  Female     No  Thur   Lunch              6
# 141       34.30   6.70    Male     No  Thur   Lunch              6
# 143       27.05   5.00  Female     No  Thur   Lunch              6
# 156       48.17   5.00    Male     No   Sun  Dinner              6
# 170       50.81  10.00    Male    Yes   Sat  Dinner              3
# 212       48.33   9.00    Male     No   Sat  Dinner              4

# %%
df[(df["day"]=='Sun') & (df['gender']=='Male')]
# Out:
#      total_bill   tip gender smoker  day    time  no_of_members
# 1         10.34  1.66   Male     No  Sun  Dinner              3
# 2         21.01  3.50   Male     No  Sun  Dinner              3
# 3         23.68  3.31   Male     No  Sun  Dinner              2
# 5         25.29  4.71   Male     No  Sun  Dinner              4
# 6          8.77  2.00   Male     No  Sun  Dinner              2
# 7         26.88  3.12   Male     No  Sun  Dinner              4
# 8         15.04  1.96   Male     No  Sun  Dinner              2
# 9         14.78  3.23   Male     No  Sun  Dinner              2
# 10        10.27  1.71   Male     No  Sun  Dinner              2
# 12        15.42  1.57   Male     No  Sun  Dinner              2
# 13        18.43  3.00   Male     No  Sun  Dinner              4
# 15        21.58  3.92   Male     No  Sun  Dinner              2
# 17        16.29  3.71   Male     No  Sun  Dinner              3
# 41        17.46  2.54   Male     No  Sun  Dinner              2
# ...

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'gender', 'smoker', 'day', 'time',
#        'no_of_members'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   total_bill     244 non-null    float64
#  1   tip            244 non-null    float64
#  2   gender         244 non-null    object
#  3   smoker         244 non-null    object
#  4   day            244 non-null    object
#  5   time           244 non-null    object
#  6   no_of_members  244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
dicrete_categorical = ['gender', 'smoker', 'day', 'time']

# %%
df['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['gender'].value_counts()
# Out:
# gender
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df['smoker'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
df['day'].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
df['time'].unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
df['time'].value_counts()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
df[dicrete_categorical].describe()
# Out:
#        gender smoker  day    time
# count     244    244  244     244
# unique      2      2    4       2
# top      Male     No  Sat  Dinner
# freq      157    151   87     176

# %%
df['gender'].value_counts()/len(df)
# Out:
# gender
# Male      0.643443
# Female    0.356557
# Name: count, dtype: float64

# %%
df['gender'].value_counts(normalize=True)
# Out:
# gender
# Male      0.643443
# Female    0.356557
# Name: proportion, dtype: float64

# %%
pd.crosstab(df['gender'],df['smoker'])
# Out:
# smoker  No  Yes
# gender
# Female  54   33
# Male    97   60

# %%
pd.crosstab(df['gender'],df['day'])
# Out:
# day     Fri  Sat  Sun  Thur
# gender
# Female    9   28   18    32
# Male     10   59   58    30

# %%
pd.crosstab(df['gender'],df['time'])
# Out:
# time    Dinner  Lunch
# gender
# Female      52     35
# Male       124     33

# %%
pd.crosstab(df['gender'],df['time'],margins=True)
# Out:
# time    Dinner  Lunch  All
# gender
# Female      52     35   87
# Male       124     33  157
# All        176     68  244
